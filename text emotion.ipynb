# %%
# !pip install transformers

from transformers import pipeline

# Load the emotion classifier
emotion_classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=True)

# Input sentence
text = "happy to see you"

# Run classification
results = emotion_classifier(text)

# Get the top emotion
top_emotion = max(results[0], key=lambda x: x['score'])

# Format and display result
label = top_emotion['label'].capitalize()
score = top_emotion['score'] * 100  # Convert to percentage

print(f"The sentence refers to **{label}** with **{score:.2f}%** accuracy.")
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
# !pip install transformers

from transformers import pipeline

# Load emotion classifier
emotion_classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=True)

# Example usage
text = "I miss you so much, it hurts inside."
results = emotion_classifier(text)

for emotion in results[0]:
    print(f"{emotion['label']}: {emotion['score']:.4f}")
# Out:
# ...
# Device set to use cuda:0
# anger: 0.0010
# disgust: 0.0026
# fear: 0.0013
# joy: 0.0018
# neutral: 0.0119
# sadness: 0.9780
# surprise: 0.0035

# %%
# Ask user for input
user_text = input("Enter a sentence to analyze emotion: ")

# Run the classifier
results = emotion_classifier(user_text)

# Get the top emotion
top_emotion = max(results[0], key=lambda x: x['score'])

# Print result
print(f'The sentence refers to **{top_emotion["label"]}** with **{top_emotion["score"] * 100:.2f}%** confidence.')
# Out:
# Enter a sentence to analyze emotion: the food looks very bad
# The sentence refers to **disgust** with **74.96%** confidence.

# %%
# !pip install datasets

from datasets import load_dataset

df = load_dataset("go_emotions")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 11.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...

# %%
# !pip install transformers==4.28.1
import transformers
print(transformers.__version__)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.0/110.0 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 68.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 71.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.28.1 which is incompatible.
# ...
# 4.51.3

# %%
import pandas as pd
from datasets import load_dataset

df = load_dataset("go_emotions")

# Access the 'train' split within the DatasetDict and convert to DataFrame
train_df = pd.DataFrame(df["train"])

# Now you can use head() on the DataFrame
train_df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#                                                 text labels       id
# 0  My favourite food is anything I didn't have to...   [27]  eebbqej
# 1  Now if he does off himself, everyone will thin...   [27]  ed00q6i
# 2                     WHY THE FUCK IS BAYLESS ISOING    [2]  eezlygj
# 3                        To make her feel threatened   [14]  ed7ypvh
# 4                             Dirty Southern Wankers    [3]  ed0bdzj

# %%
# !pip install datasets --upgrade
# !pip install evaluate

# Import libraries
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
import numpy as np
# Upgrade datasets and import load_metric
from evaluate import load # Import load from evaluate

# Load dataset
dataset = load_dataset("go_emotions")

# Load tokenizer
model_checkpoint = "distilbert-base-uncased"  # or any model you want
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# Prepare dataset
def tokenize_function(examples):
    # added padding="max_length" and max_length=128
    # This will ensure all sequences have the same length
    tokens = tokenizer(examples['text'], truncation=True, padding="max_length", max_length=128)
    tokens["labels"] = [label[0] if isinstance(label, list) else label for label in examples["labels"]]
    return tokens

# Tokenize both train and validation sets
tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Load model
model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint, num_labels=28)  # GoEmotions has 28 emotions

# Define metric
metric = load("accuracy") # Use load from evaluate instead of load_metric

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)


from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,
    # Report evaluation metrics at the end of each epoch
    # You can customize the metric
    metric_for_best_model="accuracy",
    load_best_model_at_end=True, # Load the best model at the end of training
    # Align save strategy with evaluation strategy
    save_strategy="epoch"
)

# Define Trainer, including the validation set and compute_metrics
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"], # Specify training set
    eval_dataset=tokenized_dataset["validation"], # Specify validation set
    compute_metrics=compute_metrics # Pass the compute_metrics function
)

# Start fine-tuning
trainer.train()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.8 MB/s eta 0:00:00
# ...
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# ...
# Map:   0%|          | 0/5427 [00:00<?, ? examples/s]
# ...

# %%
# !pip install datasets --upgrade

# %%
results = trainer.evaluate(tokenized_dataset["test"])
print(results)
# Out:
#     <div>
#
#       <progress value='679' max='679' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [679/679 00:23]
#     </div>
# {'eval_loss': 1.395635962486267, 'eval_accuracy': 0.5826423438363737, 'eval_runtime': 23.9758, 'eval_samples_per_second': 226.354, 'eval_steps_per_second': 28.32, 'epoch': 3.0}

# %%
results = trainer.evaluate(tokenized_dataset["test"])
print(results)
# Out:
#     <div>
#
#       <progress value='1358' max='679' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [679/679 02:52]
#     </div>
# {'eval_loss': 1.395635962486267, 'eval_accuracy': 0.5826423438363737, 'eval_runtime': 23.1, 'eval_samples_per_second': 234.935, 'eval_steps_per_second': 29.394, 'epoch': 3.0}

# %%
# Your random input
text = "I am feeling so frustrated and angry!"

# Tokenize the input
inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=128)

# Import torch
import torch

# Move model and inputs to the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)
inputs = inputs.to(device)

# Predict
outputs = model(**inputs)
logits = outputs.logits

# Get predicted class id
predicted_class_id = torch.argmax(logits, dim=-1).item()

# Map class id to label (GoEmotions 28 labels)
id2label = {
    0: 'admiration', 1: 'amusement', 2: 'anger', 3: 'annoyance', 4: 'approval', 5: 'caring',
    6: 'confusion', 7: 'curiosity', 8: 'desire', 9: 'disappointment', 10: 'disapproval',
    11: 'disgust', 12: 'embarrassment', 13: 'excitement', 14: 'fear', 15: 'gratitude',
    16: 'grief', 17: 'joy', 18: 'love', 19: 'nervousness', 20: 'optimism', 21: 'pride',
    22: 'realization', 23: 'relief', 24: 'remorse', 25: 'sadness', 26: 'surprise', 27: 'neutral'
}

# Print predicted emotion
print(f"Predicted emotion: {id2label[predicted_class_id]}")
# Out:
# Predicted emotion: anger

# %%
# Save model and tokenizer
model.save_pretrained("./my_goemotions_model")
tokenizer.save_pretrained("./my_goemotions_model")
# Out:
# ('./my_goemotions_model/tokenizer_config.json',
#  './my_goemotions_model/special_tokens_map.json',
#  './my_goemotions_model/vocab.txt',
#  './my_goemotions_model/added_tokens.json',
#  './my_goemotions_model/tokenizer.json')

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# Load model and tokenizer
model = AutoModelForSequenceClassification.from_pretrained("./my_goemotions_model")
tokenizer = AutoTokenizer.from_pretrained("./my_goemotions_model")

# %%
import torch

# Move model to device (GPU if available)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)
model.eval()  # IMPORTANT: Set model to evaluation mode

# Your random input
text ="I cant wait for the weekend, Im excited to relax and have fun with friends"

# Tokenize the input
inputs = tokenizer(text, return_tensors="pt", truncation=True, padding="max_length", max_length=128)

# Move inputs to same device as model
inputs = inputs.to(device)

# Predict
with torch.no_grad():  # No gradients needed for inference
    outputs = model(**inputs)
    logits = outputs.logits

# Get predicted class id
predicted_class_id = torch.argmax(logits, dim=-1).item()

# Your id2label mapping (GoEmotions 28 labels)
id2label = {
    0: 'admiration', 1: 'amusement', 2: 'anger', 3: 'annoyance', 4: 'approval', 5: 'caring',
    6: 'confusion', 7: 'curiosity', 8: 'desire', 9: 'disappointment', 10: 'disapproval',
    11: 'disgust', 12: 'embarrassment', 13: 'excitement', 14: 'fear', 15: 'gratitude',
    16: 'grief', 17: 'joy', 18: 'love', 19: 'nervousness', 20: 'optimism', 21: 'pride',
    22: 'realization', 23: 'relief', 24: 'remorse', 25: 'sadness', 26: 'surprise', 27: 'neutral'
}

# Print predicted emotion
print(f"Predicted emotion: {id2label[predicted_class_id]}")
# Out:
# Predicted emotion: excitement

# %%
# !zip -r my_goemotions_model.zip my_goemotions_model
# Out:
# updating: my_goemotions_model/ (stored 0%)
# updating: my_goemotions_model/pytorch_model.bin (deflated 8%)
# updating: my_goemotions_model/special_tokens_map.json (deflated 42%)
# updating: my_goemotions_model/tokenizer_config.json (deflated 43%)
# updating: my_goemotions_model/vocab.txt (deflated 53%)
# updating: my_goemotions_model/config.json (deflated 65%)
# updating: my_goemotions_model/tokenizer.json (deflated 71%)
